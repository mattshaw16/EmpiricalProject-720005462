# %% [raw]
# import csv
# import os
#
# #define folder path
# folder_path = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\PlayerData"
#
# #define values for seasons
# seasons = ['1992/93', '2002/03', '2012/13', '2022/23']
#
# #for loop to iterate over each file
# for index, filename in enumerate(os.listdir(folder_path)):
#     if filename.endswith(".csv"):
#         file_path = os.path.join(folder_path, filename)
#
#         #get season value
#         season = seasons[index]
#
#         #open CSV for editing
#         with open(file_path, 'r', newline='') as file:
#             reader = csv.reader(file)
#             data = list(reader)
#
#         #insert column header
#         data[0].insert(7, 'Season')
#
#         #insert values into the column
#         for row in data[1:]:
#             row.insert(7, season)
#
#         with open(file_path, 'w', newline='') as file:
#             writer = csv.writer(file)
#             writer.writerows(data)

# %%
import os
import pandas as pd

#define folder path containing the CSV files
folder_path = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\PlayerData"

#empty list to store dfs
dfs = []

#for loop to iterate over each file
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(folder_path, filename)
        
        #read the CSV file into a df
        #encode with latin-1 
        df = pd.read_csv(file_path, encoding='latin-1')
        
        #append df to list
        dfs.append(df)

#merge df
merged_df = pd.concat(dfs, ignore_index=True)

print(merged_df)
# Out:
#            Player Name     Position  Nationality                 Club  Height  \
# 0          Gary Ablett     Defender      England              Everton   188cm
# 1           Tony Adams     Defender      England              Arsenal   191cm
# 2          Steve Agnew   Midfielder      England     Blackburn Rovers   178cm
# 3          Derek Allan     Defender     Scotland          Southampton   183cm
# 4        Bradley Allen      Forward      England  Queens Park Rangers   170cm
# ...                ...          ...          ...                  ...     ...
# 3180      Ben Woodburn   Midfielder        Wales            Liverpool   174cm
# 3181   Freddie Woodman   Goalkeeper      England  Bournemouth  (Loan)   188cm
# 3182  Joe Wormleighton     Defender      England       Leicester City
# 3183       Joe Worrall     Defender      England    Nottingham Forest   193cm
# 3184      James Wright   Goalkeeper      England          Aston Villa
#
#                     DoB  Goals   Season
# 0            19/11/1965      0  1992/93
# 1            10/10/1966      0  1992/93
# 2            09/11/1965      0  1992/93
# 3            24/12/1974      0  1992/93
# 4            13/09/1971     10  1992/93
# ...                 ...    ...      ...
# 3180         15/10/1999      0  2022/23
# 3181         04/03/1997      0  2022/23
# 3182         30/12/2003      0  2022/23
# 3183         10/01/1997      1  2022/23
# 3184   02/12/2004  (19)      0  2022/23
#
# [3185 rows x 8 columns]

# %%
import numpy as np

#strips any leading whitespace
#fixed in web scrape code now but due to time taken to generate data white space has been stripped
merged_df = merged_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
merged_df.columns = [column.strip() for column in merged_df.columns]

#keeps only birth date
merged_df['DoB'] = merged_df['DoB'].str.slice(0, 10)

#replaces any empty value with a NaN
merged_df.replace('', np.nan, inplace=True)

print(merged_df)
# Out:
#            Player Name    Position Nationality                 Club Height  \
# 0          Gary Ablett    Defender     England              Everton  188cm
# 1           Tony Adams    Defender     England              Arsenal  191cm
# 2          Steve Agnew  Midfielder     England     Blackburn Rovers  178cm
# 3          Derek Allan    Defender    Scotland          Southampton  183cm
# 4        Bradley Allen     Forward     England  Queens Park Rangers  170cm
# ...                ...         ...         ...                  ...    ...
# 3180      Ben Woodburn  Midfielder       Wales            Liverpool  174cm
# 3181   Freddie Woodman  Goalkeeper     England  Bournemouth  (Loan)  188cm
# 3182  Joe Wormleighton    Defender     England       Leicester City    NaN
# 3183       Joe Worrall    Defender     England    Nottingham Forest  193cm
# 3184      James Wright  Goalkeeper     England          Aston Villa    NaN
#
#              DoB Goals   Season
# 0     19/11/1965     0  1992/93
# 1     10/10/1966     0  1992/93
# 2     09/11/1965     0  1992/93
# 3     24/12/1974     0  1992/93
# 4     13/09/1971    10  1992/93
# ...          ...   ...      ...
# 3180  15/10/1999     0  2022/23
# 3181  04/03/1997     0  2022/23
# 3182  30/12/2003     0  2022/23
# 3183  10/01/1997     1  2022/23
# 3184  02/12/2004     0  2022/23
#
# [3185 rows x 8 columns]
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\2042184854.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   merged_df = merged_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
#counts the number of rows with null values
num_rows_with_null = merged_df.isnull().any(axis=1).sum()
print("Number of rows with null values:", num_rows_with_null)


#counts the number of rows with null values excluding the 'height' column as lots of missing data in this column
merged_df_temp = merged_df.drop(columns=['Height'])
num_rows_with_null = merged_df_temp.isnull().any(axis=1).sum()
print("Number of rows with null values (excluding 'Height' column):", num_rows_with_null)


#drops rows with NaN values in any column except 'height'
merged_df = merged_df.dropna(subset=[col for col in merged_df.columns if col != 'Height'])
print(merged_df)
# Out:
# Number of rows with null values: 238
# Number of rows with null values (excluding 'Height' column): 15
#            Player Name    Position Nationality                 Club Height  \
# 0          Gary Ablett    Defender     England              Everton  188cm
# 1           Tony Adams    Defender     England              Arsenal  191cm
# 2          Steve Agnew  Midfielder     England     Blackburn Rovers  178cm
# 3          Derek Allan    Defender    Scotland          Southampton  183cm
# 4        Bradley Allen     Forward     England  Queens Park Rangers  170cm
# ...                ...         ...         ...                  ...    ...
# 3180      Ben Woodburn  Midfielder       Wales            Liverpool  174cm
# 3181   Freddie Woodman  Goalkeeper     England  Bournemouth  (Loan)  188cm
# 3182  Joe Wormleighton    Defender     England       Leicester City    NaN
# 3183       Joe Worrall    Defender     England    Nottingham Forest  193cm
# 3184      James Wright  Goalkeeper     England          Aston Villa    NaN
#
#              DoB Goals   Season
# 0     19/11/1965     0  1992/93
# 1     10/10/1966     0  1992/93
# 2     09/11/1965     0  1992/93
# 3     24/12/1974     0  1992/93
# 4     13/09/1971    10  1992/93
# ...          ...   ...      ...
# 3180  15/10/1999     0  2022/23
# 3181  04/03/1997     0  2022/23
# 3182  30/12/2003     0  2022/23
# 3183  10/01/1997     1  2022/23
# 3184  02/12/2004     0  2022/23
#
# [3170 rows x 8 columns]

# %%
#group the df by 'Season' and count the number of unique nationalities for each season
unique_countries_per_season = merged_df.groupby('Season')['Nationality'].nunique().reset_index()

#rename columns
unique_countries_per_season.columns = ['Season', 'Unique Countries']

print(unique_countries_per_season)
# Out:
#     Season  Unique Countries
# 0  1992/93                28
# 1  2002/03                77
# 2  2012/13                87
# 3  2022/23                84

# %%
#get the unique seasons in the df
unique_seasons = merged_df['Season'].unique()

#create an empty dictionary to store dfs for each season
season_dataframes = {}

#for loop to iterate over each season
for season in unique_seasons:
    #filter df for the current season
    season_df = merged_df[merged_df['Season'] == season]
    
    #calculate the total number of rows for each unique nationality
    nationality_counts = season_df['Nationality'].value_counts()
    
    #create a df from the value counts
    nationality_counts_df = pd.DataFrame({'Nationality': nationality_counts.index, 'No. Players': nationality_counts.values})

    #rank based on number of players for each nation
    nationality_counts_df = nationality_counts_df.sort_values(by='No. Players', ascending=False)
    nationality_counts_df['Rank'] = nationality_counts_df['No. Players'].rank(method='dense', ascending=False)
    nationality_counts_df['Rank'] = nationality_counts_df['Rank'].astype(int)

    #calculate the percentage of players for each nationality
    total_players = nationality_counts_df['No. Players'].sum()
    nationality_counts_df['Percentage'] = (nationality_counts_df['No. Players'] / total_players) * 100
    
    #store the df for the current season in the dictionary
    season_dataframes[season] = nationality_counts_df

#print dfs
for season, df in season_dataframes.items():
    print(f"Season: {season}")
    print(df)
# Out:
# Season: 1992/93
#          Nationality  No. Players  Rank  Percentage
# 0            England          388     1   71.062271
# 1           Scotland           39     2    7.142857
# 2            Ireland           26     3    4.761905
# 3              Wales           26     3    4.761905
# 4   Northern Ireland           13     4    2.380952
# 5             Norway            8     5    1.465201
# 6            Denmark            5     6    0.915751
# 7        Netherlands            4     7    0.732601
# 8          Australia            4     7    0.732601
# 9            Jamaica            3     8    0.549451
# 10     United States            3     8    0.549451
# 11            Canada            3     8    0.549451
# 12            Sweden            3     8    0.549451
# 16           Germany            2     9    0.366300
# 18            Poland            2     9    0.366300
# 17            Russia            2     9    0.366300
# 14          Zimbabwe            2     9    0.366300
# 15           Iceland            2     9    0.366300
# 13           Nigeria            2     9    0.366300
# 19            France            1    10    0.183150
# 20   North Macedonia            1    10    0.183150
# 21        Montserrat            1    10    0.183150
# 22          Bulgaria            1    10    0.183150
# 23             Malta            1    10    0.183150
# 24           Hungary            1    10    0.183150
# 25             Spain            1    10    0.183150
# 26            Israel            1    10    0.183150
# 27    Czech Republic            1    10    0.183150
# 1066
# Season: 2002/03
#                  Nationality  No. Players  Rank  Percentage
# 0                    England          307     1   41.042781
# 1                    Ireland           63     2    8.422460
# 2                     France           47     3    6.283422
# 3                   Scotland           32     4    4.278075
# 4                    Denmark           19     5    2.540107
# ..                       ...          ...   ...         ...
# 50           North Macedonia            1    19    0.133690
# 49         Antigua & Barbuda            1    19    0.133690
# 48                   Estonia            1    19    0.133690
# 47                  Bulgaria            1    19    0.133690
# 76  Central African Republic            1    19    0.133690
#
# [77 rows x 4 columns]
# 1066
# Season: 2012/13
#           Nationality  No. Players  Rank  Percentage
# 0             England          304     1   37.530864
# 1             Ireland           42     2    5.185185
# 2               Spain           35     3    4.320988
# 3              France           33     4    4.074074
# 4            Scotland           24     5    2.962963
# ..                ...          ...   ...         ...
# 68            Bolivia            1    19    0.123457
# 67              Benin            1    19    0.123457
# 66  St. Kitts & Nevis            1    19    0.123457
# 65         Montenegro            1    19    0.123457
# 86           Slovenia            1    19    0.123457
#
# [87 rows x 4 columns]
# 1066
# Season: 2022/23
#    Nationality  No. Players  Rank  Percentage
# 0      England          422     1   39.587242
# 1       Brazil           47     2    4.409006
# 2       France           46     3    4.315197
# 3        Spain           43     4    4.033771
# 4      Ireland           38     5    3.564728
# ..         ...          ...   ...         ...
# 70  Cape Verde            1    21    0.093809
# 69   Nicaragua            1    21    0.093809
# 68      Guyana            1    21    0.093809
# 67      Kosovo            1    21    0.093809
# 83    Thailand            1    21    0.093809
#
# [84 rows x 4 columns]
# 1066

# %%
import matplotlib.pyplot as plt

#for loop iterates over all seasons
for season, df in season_dataframes.items():

    #calculate the total number of players
    total_players = df['No. Players'].sum()

    #identify nationalities that make up less than 2% of the total
    mask = df['Percentage'] < 2

    #create a new df for nationalities under the threshold
    others = df[mask]

    #sum the 'Others' category
    others_sum = others['No. Players'].sum()

    #remove the countries that are less than 2% from the original DataFrame
    filtered_nationalities = df[~mask]

    #append the 'Others' row to the end of the df
    new_row = pd.DataFrame({'Nationality': ['Others'], 'No. Players': [others_sum], 'Proportion': [(others_sum / total_players) * 100]})
    filtered_nationalities = pd.concat([filtered_nationalities, new_row], ignore_index=True)

    #print rows of 'Others' where 'No. Players' is greater than 5
    filtered_others_df = others[others['No. Players'] > 5]
    print(filtered_others_df)

    #plot pie chart
    plt.figure(figsize=(8, 6))
    plt.pie(filtered_nationalities['No. Players'], labels=filtered_nationalities['Nationality'], autopct='%1.1f%%', startangle=90)
    plt.title(f'Proportion of Players by Nationality for Season {season}')
    plt.axis('equal')  

    #saves figure to project directory
    save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
    file_name = f'Pie_Nationalities_Season_{season.replace("/", "-")}.png'
    plt.savefig(os.path.join(save_directory, file_name))
    
    plt.show()
# Out:
#   Nationality  No. Players  Rank  Percentage
# 5      Norway            8     5    1.465201
#          Nationality  No. Players  Rank  Percentage
# 10  Northern Ireland           11     9    1.470588
# 11           Finland           10    10    1.336898
# 12             Italy            9    11    1.203209
# 13           Germany            9    11    1.203209
# 14           Iceland            8    12    1.069519
# 15         Argentina            8    12    1.069519
# 16             Spain            7    13    0.935829
# 17           Nigeria            7    13    0.935829
# 18           Jamaica            7    13    0.935829
# 21            Brazil            6    14    0.802139
# 22          Portugal            6    14    0.802139
# 20          Cameroon            6    14    0.802139
# 19     United States            6    14    0.802139
#          Nationality  No. Players  Rank  Percentage
# 9   Northern Ireland           13     8    1.604938
# 11           Germany           13     8    1.604938
# 10         Argentina           13     8    1.604938
# 12          Portugal           12     9    1.481481
# 13         Australia           12     9    1.481481
# 14           Jamaica           10    10    1.234568
# 15     United States            9    11    1.111111
# 16     Cote DIvoire            9    11    1.111111
# 17             Italy            9    11    1.111111
# 19       Switzerland            8    12    0.987654
# 20              Mali            8    12    0.987654
# 18           Senegal            8    12    0.987654
# 21            Norway            7    13    0.864198
# 22            Sweden            6    14    0.740741
# 23    Czech Republic            6    14    0.740741
# 24          Cameroon            6    14    0.740741
# 25           Nigeria            6    14    0.740741
# 26          Slovakia            6    14    0.740741
# 27           Denmark            6    14    0.740741
#          Nationality  No. Players  Rank  Percentage
# 9            Denmark           21     8    1.969981
# 11     United States           18     9    1.688555
# 10           Belgium           18     9    1.688555
# 12           Germany           16    10    1.500938
# 13         Argentina           15    11    1.407129
# 14            Poland           15    11    1.407129
# 15  Northern Ireland           12    12    1.125704
# 16             Ghana           11    13    1.031895
# 17             Italy           11    13    1.031895
# 18           Jamaica           11    13    1.031895
# 22           Nigeria            9    14    0.844278
# 21     Cote DIvoire            9    14    0.844278
# 20          Colombia            9    14    0.844278
# 19            Sweden            9    14    0.844278
# 23       Switzerland            7    15    0.656660
# 24            Norway            7    15    0.656660
# 25           Senegal            7    15    0.656660
# 26           Uruguay            6    16    0.562852
# 27    Czech Republic            6    16    0.562852
# 28           Croatia            6    16    0.562852
# 29           Ecuador            6    16    0.562852

# %%
#dictionary to store dfs for each season
season_dfs = {}

#for loop to terate over each season
for season, df_season in merged_df.groupby('Season'):
    #create a new DataFrame with 'position', 'season', and 'club'
    new_df = df_season[['Position', 'Season', 'Club']].copy()
    
    #remove '(loan)', 'U18', and 'U21' from club names at the end of the string after stripping whitespace
    new_df['Club'] = new_df['Club'].str.replace(r'\s*(\(Loan\)|U18|U21)\s*', '', regex=True)

    
    #group by 'Club', and 'Position'
    grouped_df = new_df.groupby(['Club', 'Position']).size().reset_index(name='Count')
    
    #pivot the df so that clubs are rows and positions are columns
    pivot_df = grouped_df.pivot_table(index='Club', columns='Position', values='Count', aggfunc='sum', fill_value=0)
    
    #add a total column
    pivot_df['Total Squad'] = pivot_df.sum(axis=1)

    #add proportion columns
    pivot_df['Proportion Defender'] = (pivot_df['Defender'] / pivot_df['Total Squad']) * 100
    pivot_df['Proportion Forward'] = (pivot_df['Forward'] / pivot_df['Total Squad']) * 100
    pivot_df['Proportion Goalkeeper'] = (pivot_df['Goalkeeper'] / pivot_df['Total Squad']) * 100
    pivot_df['Proportion Midfielder'] = (pivot_df['Midfielder'] / pivot_df['Total Squad']) * 100
    
    #store the dataset for the current season
    season_dfs[season] = pivot_df

#print each df
for season, dataset in season_dfs.items():
    print(f"Dataset for {season}:")
    print(dataset)
    print("\n")
# Out:
# Dataset for 1992/93:
# Position             Defender  Forward  Goalkeeper  Midfielder  Total Squad  \
# Club
# Arsenal                    12        5           2          10           29
# Aston Villa                 8        6           3          12           29
# Blackburn Rovers            8        5           3          11           27
# Chelsea                    12        7           6           9           34
# Southampton                    15       13           4          17
# Tottenham Hotspur              21       13           6          16
# West Ham United                14        9           6          16
# Wolverhampton Wanderers        17       14           7          15
#
# Position                 Total Squad  Proportion Defender  Proportion Forward  \
# Club
# Arsenal                           60            36.666667           20.000000
# Aston Villa                       47            36.170213           12.765957
# Bournemouth                       54            33.333333           18.518519
# Brentford                         49            32.653061           16.326531
# Brighton & Hove Albion            55            29.090909           21.818182
# Chelsea                           66            34.848485           16.666667
# Crystal Palace                    54            31.481481           18.518519
# Everton                           58            31.034483           22.413793
# Fulham                            53            35.849057           22.641509
# Leeds United                      54            29.629630           25.925926
# Leicester City                    51            33.333333           11.764706
# Liverpool                         56            26.785714           25.000000
# Manchester City                   54            37.037037           18.518519
# Manchester United                 57            29.824561           24.561404
# Newcastle United                  35            34.285714           17.142857
# Nottingham Forest                 59            35.593220           25.423729
# Sheffield United                   1             0.000000            0.000000
# Southampton                       49            30.612245           26.530612
# Tottenham Hotspur                 56            37.500000           23.214286
# West Ham United                   45            31.111111           20.000000
# Wolverhampton Wanderers           53            32.075472           26.415094
#
# Position                 Proportion Goalkeeper  Proportion Midfielder
# Club
# Arsenal                              11.666667              31.666667
# Aston Villa                          12.765957              38.297872
# Bournemouth                          11.111111              37.037037
# Brentford                            14.285714              36.734694
# Brighton & Hove Albion                9.090909              40.000000
# Chelsea                              15.151515              33.333333
# Crystal Palace                        9.259259              40.740741
# Everton                              13.793103              32.758621
# Fulham                               11.320755              30.188679
# Leeds United                         12.962963              31.481481
# Leicester City                        9.803922              45.098039
# Liverpool                            10.714286              37.500000
# Manchester City                      12.962963              31.481481
# Manchester United                    14.035088              31.578947
# Newcastle United                     14.285714              34.285714
# Nottingham Forest                    10.169492              28.813559
# Sheffield United                      0.000000             100.000000
# Southampton                           8.163265              34.693878
# Tottenham Hotspur                    10.714286              28.571429
# West Ham United                      13.333333              35.555556
# Wolverhampton Wanderers              13.207547              28.301887

# %%
import matplotlib.pyplot as plt

#empty lists to store average, min, and max data
avg_data = []
min_data = []
max_data = []

#for loop to iterate over each season
for season, df in season_dfs.items():
    #filters out any 'team' which is not in PL e.g. EFL player was on loan for half the season to a PL club
    filtered_df = df[df['Total Squad'] > 15]
    avg_data.append(filtered_df.mean())
    min_data.append(filtered_df.min())
    max_data.append(filtered_df.max())

#lists to dfs
avg_df = pd.DataFrame(avg_data, index=season_dfs.keys())
min_df = pd.DataFrame(min_data, index=season_dfs.keys())
max_df = pd.DataFrame(max_data, index=season_dfs.keys())

#plotting
plt.figure(figsize=(12, 8))
plt.plot(avg_df.index, avg_df['Total Squad'], label='Average Total Squad', marker='o', color='blue')
plt.plot(min_df.index, min_df['Total Squad'], label='Minimum Total Squad', marker='o', color='green')
plt.plot(max_df.index, max_df['Total Squad'], label='Maximum Total Squad', marker='o', color='red')

#add labels and legend
plt.title('Total Squad Size (Average, Minimum, Maximum)')
plt.xlabel('Season')
plt.ylabel('Total Squad Size')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Total_Squad_Size.png'))

plt.show()

# %%
#print actual values
print("Average Total Squad Size:")
print(avg_df['Total Squad'])

print("\nMaximum Total Squad Size:")
print(max_df['Total Squad'])

print("\nMinimum Total Squad Size:")
print(min_df['Total Squad'])
# Out:
# Average Total Squad Size:
# 1992/93    24.818182
# 2002/03    37.400000
# 2012/13    15.000000
# 2022/23    50.761905
# Name: Total Squad, dtype: float64
#
# Maximum Total Squad Size:
# 1992/93    34.0
# 2002/03    48.0
# 2012/13    55.0
# 2022/23    66.0
# Name: Total Squad, dtype: float64
#
# Minimum Total Squad Size:
# 1992/93    18.0
# 2002/03    29.0
# 2012/13    27.0
# 2022/23    35.0
# Name: Total Squad, dtype: float64

# %%
#empty list to store average data
avg_data = []

#for loop to iterate over each season
for season, df in season_dfs.items():
    filtered_df = df[df['Total Squad'] > 15]
    avg_data.append(df.mean())

#convert lists to dfs
avg_df = pd.DataFrame(avg_data, index=season_dfs.keys())


plt.figure(figsize=(12, 8))

#plot
plt.plot(avg_df.index, avg_df['Proportion Defender'], label='Average Defender', marker='o')
plt.plot(avg_df.index, avg_df['Proportion Forward'], label='Average Forward', marker='o')
plt.plot(avg_df.index, avg_df['Proportion Goalkeeper'], label='Average Goalkeeper', marker='o')
plt.plot(avg_df.index, avg_df['Proportion Midfielder'], label='Average Midfielder', marker='o')

#add labels and legend
plt.title('Average Squad Composition')
plt.xlabel('Season')
plt.ylabel('Percentage')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Average_Squad_Composition.png'))

plt.show()

# %%
#strip "cm" from all values in the "Height" column
merged_df['Height'] = merged_df['Height'].str.replace('cm', '')

#convert the "Height" column to numeric
merged_df['Height'] = pd.to_numeric(merged_df['Height'])

#mask out rows where 'Height' column has NaN value
height_df = merged_df[~merged_df['Height'].isna()]

print(height_df)
# Out:
#            Player Name    Position  Nationality                       Club  \
# 0          Gary Ablett    Defender      England                    Everton
# 1           Tony Adams    Defender      England                    Arsenal
# 2          Steve Agnew  Midfielder      England           Blackburn Rovers
# 3          Derek Allan    Defender     Scotland                Southampton
# 4        Bradley Allen     Forward      England        Queens Park Rangers
# ...                ...         ...          ...                        ...
# 3177  Maximilian Wöber    Defender      Austria               Leeds United
# 3179        Chris Wood     Forward  New Zealand  Nottingham Forest  (Loan)
# 3180      Ben Woodburn  Midfielder        Wales                  Liverpool
# 3181   Freddie Woodman  Goalkeeper      England        Bournemouth  (Loan)
# 3183       Joe Worrall    Defender      England          Nottingham Forest
#
#       Height         DoB Goals   Season
# 0      188.0  19/11/1965     0  1992/93
# 1      191.0  10/10/1966     0  1992/93
# 2      178.0  09/11/1965     0  1992/93
# 3      183.0  24/12/1974     0  1992/93
# 4      170.0  13/09/1971    10  1992/93
# ...      ...         ...   ...      ...
# 3177   188.0  04/02/1998     0  2022/23
# 3179   191.0  07/12/1991     1  2022/23
# 3180   174.0  15/10/1999     0  2022/23
# 3181   188.0  04/03/1997     0  2022/23
# 3183   193.0  10/01/1997     1  2022/23
#
# [2947 rows x 8 columns]

# %%
#convert height column to integer type to
height_df['Height'] = height_df['Height'].astype(int)

#create height bins
bins = np.linspace(height_df['Height'].min(), height_df['Height'].max(), 11)

#group data by height bins and seasons
height_df['Height Bin'] = pd.cut(height_df['Height'], bins=bins)
height_season_groups = height_df.groupby(['Height Bin', 'Season'])

#calculate size of each bin
height_season_counts = height_season_groups.size().unstack()

#plot
height_season_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Player Count by Height Bin and Season')
plt.xlabel('Height Bin')
plt.ylabel('Player Count')
plt.xticks(rotation=45)
plt.legend(title='Season', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Height_Bins.png'))

plt.show()
# Out:
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\3513550041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   height_df['Height'] = height_df['Height'].astype(int)
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\3513550041.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   height_df['Height Bin'] = pd.cut(height_df['Height'], bins=bins)
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\3513550041.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   height_season_groups = height_df.groupby(['Height Bin', 'Season'])

# %%
#group df by season
season_groups = merged_df.groupby('Season')

#calculate max, min, and average height for each season
max_height = season_groups['Height'].max()
min_height = season_groups['Height'].min()
avg_height = season_groups['Height'].mean()

#plot
plt.figure(figsize=(10, 6))
max_height.plot(label='Max Height', marker='o')
min_height.plot(label='Min Height', marker='o')
avg_height.plot(label='Avg Height', marker='o')

#add labels, titles, ticks etc.
plt.title('Max, Min, and Average Height for Each Season')
plt.xlabel('Season')
plt.ylabel('Height')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Height_Stats.png'))

plt.show()

# %%
#print actual values
print("Average Height:")
print(avg_height)

print("\nMaximum Height")
print(max_height)

print("\nMinimum Height:")
print(min_height)
# Out:
# Average Height:
# Season
# 1992/93    180.379182
# 2002/03    181.743207
# 2012/13    182.351117
# 2022/23    182.727797
# Name: Height, dtype: float64
#
# Maximum Height
# Season
# 1992/93    196.0
# 2002/03    201.0
# 2012/13    203.0
# 2022/23    204.0
# Name: Height, dtype: float64
#
# Minimum Height:
# Season
# 1992/93    165.0
# 2002/03    163.0
# 2012/13    160.0
# 2022/23    163.0
# Name: Height, dtype: float64

# %%
#code to calculate age from DoB column

#converts DoB column to datetime format
merged_df['DoB'] = pd.to_datetime(merged_df['DoB'])

#cretaes a new column with the season start year
merged_df['Season Start Year'] = merged_df['Season'].str[:4]

#calculates age
merged_df['Age'] = ((merged_df['Season Start Year'].astype(int) +1) - merged_df['DoB'].dt.year)

print(merged_df)
# Out:
#            Player Name    Position Nationality                 Club  Height  \
# 0          Gary Ablett    Defender     England              Everton   188.0
# 1           Tony Adams    Defender     England              Arsenal   191.0
# 2          Steve Agnew  Midfielder     England     Blackburn Rovers   178.0
# 3          Derek Allan    Defender    Scotland          Southampton   183.0
# 4        Bradley Allen     Forward     England  Queens Park Rangers   170.0
# ...                ...         ...         ...                  ...     ...
# 3180      Ben Woodburn  Midfielder       Wales            Liverpool   174.0
# 3181   Freddie Woodman  Goalkeeper     England  Bournemouth  (Loan)   188.0
# 3182  Joe Wormleighton    Defender     England       Leicester City     NaN
# 3183       Joe Worrall    Defender     England    Nottingham Forest   193.0
# 3184      James Wright  Goalkeeper     England          Aston Villa     NaN
#
#             DoB Goals   Season Season Start Year  Age
# 0    1965-11-19     0  1992/93              1992   28
# 1    1966-10-10     0  1992/93              1992   27
# 2    1965-11-09     0  1992/93              1992   28
# 3    1974-12-24     0  1992/93              1992   19
# 4    1971-09-13    10  1992/93              1992   22
# ...         ...   ...      ...               ...  ...
# 3180 1999-10-15     0  2022/23              2022   24
# 3181 1997-03-04     0  2022/23              2022   26
# 3182 2003-12-30     0  2022/23              2022   20
# 3183 1997-01-10     1  2022/23              2022   26
# 3184 2004-12-02     0  2022/23              2022   19
#
# [3170 rows x 10 columns]
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\3576067048.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   merged_df['DoB'] = pd.to_datetime(merged_df['DoB'])

# %%
#creates age bins
bins = np.linspace(merged_df['Age'].min(), merged_df['Age'].max(), 11)

#group data by age bins and seasons
merged_df['Age Bin'] = pd.cut(merged_df['Age'], bins=bins)
age_season_groups = merged_df.groupby(['Age Bin', 'Season'])

#calculate size of each bin
age_season_counts = age_season_groups.size().unstack()

#plot and add titles, labels ticks etc.
age_season_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Player Count by Age Bin and Season')
plt.xlabel('Age Bin')
plt.ylabel('Player Count')
plt.xticks(rotation=45)
plt.legend(title='Season', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Age_Bins'))

plt.show()
# Out:
# C:\Users\matts\AppData\Local\Temp\ipykernel_37512\2486870218.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_season_groups = merged_df.groupby(['Age Bin', 'Season'])

# %%
#group df by season
season_groups = merged_df.groupby('Season')

#calculate max, min, and average age for each season
max_age = season_groups['Age'].max()
min_age = season_groups['Age'].min()
avg_age = season_groups['Age'].mean()

#plot
plt.figure(figsize=(10, 6))
max_age.plot(label='Max Age', marker='o')
min_age.plot(label='Min Age', marker='o')
avg_age.plot(label='Avg Age', marker='o')

#add labels, titles, ticks etc.
plt.title('Max, Min, and Average Age for Each Season')
plt.xlabel('Season')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()

#save to directory
save_directory = r"C:\Users\matts\Documents\Empirical Project\EmpiricalProject-720005462\Graphs"
plt.savefig(os.path.join(save_directory, 'Age_Stats.png'))

plt.show()
